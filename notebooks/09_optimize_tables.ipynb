# %%
# %sql

OPTIMIZE dev.claims_project.silver_claims;
OPTIMIZE dev.claims_project.silver_claims_enriched;
OPTIMIZE dev.claims_project.gold_claim_lag;
OPTIMIZE dev.claims_project.gold_provider_monthly;
OPTIMIZE dev.claims_project.gold_suspicious_claims;
